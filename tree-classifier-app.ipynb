# %%
from fastai import *
from fastai.vision.all import *
from fastai.vision.widgets import *

# %%
! wget https://github.com/kurianbenoy/Tree-Classifier/releases/download/v1.0.0/export.pkl

# %%
learn = load_learner("export.pkl")

# %%
upload_btn = widgets.FileUpload()
out_pl = widgets.Output()
lbl_pred = widgets.Label()
btn_run = widgets.Button(description="Classify")

# %%
def on_click_classify(change):
    # Create an image out of the uploaded content
    img = PILImage.create(upload_btn.data[-1])
    # Clear the output associated with output widget
    out_pl.clear_output()
    # Display the image in the outpt widget
    with out_pl:
        display(img.to_thumb(128,128))
    # Make a prediction
    pred,pred_idx,probs = learn.predict(img)
    # Show the prediction on the label
    lbl_pred.value = f'Prediction: {pred}; Probability: {probs[pred_idx]:.05f}'

btn_run.on_click(on_click_classify)

# %%
VBox([widgets.Label('Select a Tree!'), 
      upload_btn, btn_run, out_pl, lbl_pred])
